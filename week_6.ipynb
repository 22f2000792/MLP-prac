# %% [markdown]
# <a href="https://colab.research.google.com/github/22f2000792/MLP-prac/blob/main/week_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_wine
wine=load_wine(as_frame=True)

# %%
wine.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %%
wine.data.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
wine.frame.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# 0                          3.92   1065.0       0
# 1                          3.40   1050.0       0
# 2                          3.17   1185.0       0
# 3                          3.45   1480.0       0
# 4                          2.93    735.0       0

# %%
wine.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
wine.target.unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# Load the wine dataset from sklearn.
#
# - Split the dataset into train and test set with 70:30 ratio with random_state = 1
#
# - Use this for all the questions that follow
#
#
# Train a Logistic Regression model with the following parameters:
#
#     max_iter = 10000
#
#     C as 0.5
#
#     random_state = 1
#
#     solver as 'sag'
#
# Compute the accuracy on the test data.

# %%
from sklearn.model_selection import  train_test_split
X_train,X_test,y_train,y_test=train_test_split(wine.data,wine.target,test_size=0.3,random_state=1)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (124, 13) (124,)
# (54, 13) (54,)

# %%
X_train.head()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 90     12.08        1.83  2.32               18.5       81.0           1.60
# 95     12.47        1.52  2.20               19.0      162.0           2.50
# 28     13.87        1.90  2.80               19.4      107.0           2.95
# 124    11.87        4.31  2.39               21.0       82.0           2.86
# 135    12.60        2.46  2.20               18.5       94.0           1.62
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 90         1.50                  0.52             1.64              2.4  1.08
# 95         2.27                  0.32             3.28              2.6  1.16
# 28         2.97                  0.37             1.76              4.5  1.25
# 124        3.03                  0.21             2.91              2.8  0.75
# 135        0.66                  0.63             0.94              7.1  0.73
#
#      od280/od315_of_diluted_wines  proline
# 90                           2.27    480.0
# 95                           2.63    937.0
# 28                           3.40    915.0
# 124                          3.64    380.0
# 135                          1.58    695.0

# %%
from sklearn.linear_model import LogisticRegression
lgr=LogisticRegression(C=0.5,solver='sag',random_state=1,max_iter=10000,n_jobs=-1)
lgr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.5, max_iter=10000, n_jobs=-1, random_state=1,
#                    solver='sag')

# %% [markdown]
# **What is the accuracy of the model on the test data? [Enter 3 decimal places]**

# %%
from sklearn.metrics import accuracy_score
lgr_pred=lgr.predict(X_test)
accuracy_score(y_test,lgr_pred)
# Out:
# 0.9444444444444444

# %% [markdown]
# **How many iterations did the algorithm take to converge?**

# %%
lgr.n_iter_
# Out:
# array([4750], dtype=int32)

# %% [markdown]
# Perform Hyperparameter tuning on a decision tree classifier with random_state = 1 and cross validation = 4. The Hyperparameter tuning is to be done over the following parameters:
#
#     criterion can be 'entropy' or 'gini'
#
#     splitter can be 'random' or 'best'
#
#     Minimum number of samples per leaf as [2,4,6,8,10]
#
#     Maximum depth as [3,4,5,6]

# %% [markdown]
# **What is the accuracy of the model on the test data? [Enter 3 decimal places]**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
para_grid={
    "criterion":['entropy','gini'],
    "splitter":['random','best'],
    "min_samples_leaf":[2,4,6,8,10],
    "max_depth":[3,4,5,6]
}
dt=DecisionTreeClassifier(random_state=1)
gs=GridSearchCV(dt,cv=4,param_grid=para_grid,scoring='accuracy',n_jobs=-1)
gs
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(random_state=1), n_jobs=-1,
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [3, 4, 5, 6],
#                          'min_samples_leaf': [2, 4, 6, 8, 10],
#                          'splitter': ['random', 'best']},
#              scoring='accuracy')

# %%
gs.fit(X_train, y_train)
gs.score(X_test,y_test)
# Out:
# 0.9074074074074074

# %% [markdown]
# **What is the value of best max_depth after training with GridSearchCV?**

# %%
gs.best_estimator_.max_depth
# Out:
# 4

# %% [markdown]
# Perform Hyperparameter tuning on an adaboost classifier with random_state = 1 and cross validation = 4. The Hyperparameter tuning is to be done over the following parameters:
#
#     Number of estimators as [100, 500, 1000]
#
#     Learning rate as [0.5, 1, 2]
#
# Compute the accuracy on the test data.

# %%
from sklearn.ensemble import AdaBoostClassifier
ada=AdaBoostClassifier(random_state=1)
para_grid_ada={
    "n_estimators":[100,500,1000],
    "learning_rate":[0.5,1,2]
}
gs_ada=GridSearchCV(ada,param_grid=para_grid_ada,cv=4,scoring='accuracy',n_jobs=-1)
gs_ada
# Out:
# GridSearchCV(cv=4, estimator=AdaBoostClassifier(random_state=1), n_jobs=-1,
#              param_grid={'learning_rate': [0.5, 1, 2],
#                          'n_estimators': [100, 500, 1000]},
#              scoring='accuracy')

# %%
gs_ada.fit(X_train, y_train)
gs_ada.score(X_test,y_test)
# Out:
# 0.9629629629629629

# %% [markdown]
# **What is the value of best n_estimators after training with GridSearchCV?**

# %%
gs_ada.best_estimator_.n_estimators
# Out:
# 100

# %% [markdown]
# Train a voting classifier by making use of the following estimators: Bagging Classifier, Random Forest Classifier, GradientBoosting Classifier with random_state = 1 for each of the estimators.
#
# Train the model on the training data and compute the score on the test data.

# %% [markdown]
# **What is the accuracy of the model on the test data? [Enter 3 decimal places]**

# %%
from sklearn.ensemble import BaggingClassifier,VotingClassifier,RandomForestClassifier,GradientBoostingClassifier
bg=BaggingClassifier(random_state=1)
rf=RandomForestClassifier(random_state=1)
gbd=GradientBoostingClassifier(random_state=1)
vc= VotingClassifier(estimators=[
        ('bg', bg), ('rf', rf), ('gbd', gbd)])

# %%
vc.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('bg', BaggingClassifier(random_state=1)),
#                              ('rf', RandomForestClassifier(random_state=1)),
#                              ('gbd',
#                               GradientBoostingClassifier(random_state=1))])

# %%
vc.score(X_test,y_test)
# Out:
# 0.9814814814814815

# %%
print('Individual base estimator accuracies:')
for name, estimator in vc.named_estimators_.items():
    print(f'{name}: {estimator.score(X_test, y_test):.3f}')
# Out:
# Individual base estimator accuracies:
# bg: 0.981
# rf: 0.981
# gbd: 0.963

# %% [markdown]
# This output shows the individual performance of each estimator (Bagging, Random Forest, Gradient Boosting) on the test data. The `VotingClassifier` then combines their predictions for its final decision.
